# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "3"

# %%
import numpy as onp
import jax.numpy as np
from jax import random, grad, vmap, jit
from jax.example_libraries import optimizers
from jax.experimental.ode import odeint
from jax.nn import relu
from jax import config

import itertools
from functools import partial
from torch.utils import data
from tqdm import trange
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# Define the neural net
def MLP(layers, activation=relu):
  ''' Vanilla MLP'''
  def init(rng_key):
      def init_layer(key, d_in, d_out):
          k1, k2 = random.split(key)
          glorot_stddev = 1. / np.sqrt((d_in + d_out) / 2.)
          W = glorot_stddev * random.normal(k1, (d_in, d_out))
          b = np.zeros(d_out)
          return W, b
      key, *keys = random.split(rng_key, len(layers))
      params = list(map(init_layer, keys, layers[:-1], layers[1:]))
      return params
  def apply(params, inputs):
      for W, b in params[:-1]:
          outputs = np.dot(inputs, W) + b
          inputs = activation(outputs)
      W, b = params[-1]
      outputs = np.dot(inputs, W) + b
      return outputs
  return init, apply

# %%
# Data generator
class DataGenerator(data.Dataset):
    def __init__(self, u, y, s, 
                 batch_size=64, rng_key=random.PRNGKey(1234)):
        'Initialization'
        self.u = u # input sample
        self.y = y # location
        self.s = s # labeled data evulated at y (solution measurements, BC/IC conditions, etc.)
        
        self.N = u.shape[0]
        self.batch_size = batch_size
        self.key = rng_key

    def __getitem__(self, index):
        'Generate one batch of data'
        self.key, subkey = random.split(self.key)
        inputs, outputs = self.__data_generation(subkey)
        return inputs, outputs

    @partial(jit, static_argnums=(0,))
    def __data_generation(self, key):
        'Generates data containing batch_size samples'
        idx = random.choice(key, self.N, (self.batch_size,), replace=False)
        s = self.s[idx,:]
        y = self.y[idx,:]
        u = self.u[idx,:]
        # Construct batch
        inputs = (u, y)
        outputs = s
        return inputs, outputs

# %%
# Define the model
class PI_DeepONet:
    def __init__(self, branch_layers, trunk_layers):    
        # Network initialization and evaluation functions
        self.branch_init, self.branch_apply = MLP(branch_layers, activation=np.tanh)
        self.trunk_init, self.trunk_apply = MLP(trunk_layers, activation=np.tanh)

        # Initialize
        branch_params = self.branch_init(rng_key = random.PRNGKey(1234))
        trunk_params = self.trunk_init(rng_key = random.PRNGKey(4321))
        params = (branch_params, trunk_params)

        # Use optimizers to set optimizer initialization and update functions
        self.opt_init, \
        self.opt_update, \
        self.get_params = optimizers.adam(optimizers.exponential_decay(1e-3, 
                                                                      decay_steps=1000, 
                                                                      decay_rate=0.9))
        self.opt_state = self.opt_init(params)

        self.itercount = itertools.count()
        
        # Loggers
        self.loss_log = []
        self.loss_operator_log = []
        self.loss_physics_log = []

    # Define DeepONet architecture
    def operator_net(self, params, u, y):
        branch_params, trunk_params = params
        B = self.branch_apply(branch_params, u)
        T = self.trunk_apply(trunk_params, y)
        outputs = np.sum(B * T)
        return outputs
    
    # Define ODE/PDE residual
    def residual_net(self, params, u, y):
        s_y = grad(self.operator_net, argnums = 2)(params, u, y)
        return s_y
    
    # Define operator loss
    def loss_operator(self, params, batch):
        # Fetch data
        # inputs: (u, y), shape = (N, m), (N,1)
        # outputs: s, shape = (N,1)
        inputs, outputs = batch
        u, y = inputs
        # Compute forward pass
        pred = vmap(self.operator_net, (None, 0, 0))(params, u, y)
        # Compute loss
        loss = np.mean((outputs.flatten() - pred.flatten())**2)
        return loss

    # Define physics loss
    def loss_physics(self, params, batch):
        # Fetch data
        # inputs: (u_r, y_r), shape = (NxQ, m), (NxQ,1)
        # outputs: s_r, shape = (NxQ, 1)
        inputs, outputs = batch
        u, y = inputs
        # Compute forward pass
        pred = vmap(self.residual_net, (None, 0, 0))(params, u, y)
        # Compute loss
        loss = np.mean((outputs.flatten() - pred.flatten())**2)
        return loss    
    
    # Define total loss
    def loss(self, params, operator_batch, physics_batch):
        loss_operator = self.loss_operator(params, operator_batch)
        loss_physics = self.loss_physics(params, physics_batch)
        loss = loss_operator + loss_physics
        return loss

    # Define a compiled update step
    @partial(jit, static_argnums=(0,))
    def step(self, i, opt_state, operator_batch, physics_batch):
        params = self.get_params(opt_state)
        g = grad(self.loss)(params, operator_batch, physics_batch)
        return self.opt_update(i, g, opt_state)

    # Optimize parameters in a loop
    def train(self, operator_dataset, physics_dataset, nIter = 10000):
        # Define the data iterator
        operator_data = iter(operator_dataset)
        physics_data = iter(physics_dataset)

        pbar = trange(nIter)
        # Main training loop
        for it in pbar:
            operator_batch= next(operator_data)
            physics_batch = next(physics_data)

            self.opt_state = self.step(next(self.itercount), self.opt_state, operator_batch, physics_batch)
            
            if it % 100 == 0:
                params = self.get_params(self.opt_state)

                # Compute losses
                loss_value = self.loss(params, operator_batch, physics_batch)
                loss_operator_value = self.loss_operator(params, operator_batch)
                loss_physics_value = self.loss_physics(params, physics_batch)

                # Store losses
                self.loss_log.append(loss_value)
                self.loss_operator_log.append(loss_operator_value)
                self.loss_physics_log.append(loss_physics_value)

                # Print losses during training
                pbar.set_postfix({'Loss': loss_value, 
                                  'loss_operator' : loss_operator_value, 
                                  'loss_physics': loss_physics_value})
       
           
    # Evaluates predictions at test points  
    @partial(jit, static_argnums=(0,))
    def predict_s(self, params, U_star, Y_star):
        s_pred = vmap(self.operator_net, (None, 0, 0))(params, U_star, Y_star)
        return s_pred

    @partial(jit, static_argnums=(0,))
    def predict_s_y(self, params, U_star, Y_star):
        s_y_pred = vmap(self.residual_net, (None, 0, 0))(params, U_star, Y_star)
        return s_y_pred

# %%
# Length scale of a Gaussian random field (GRF)
length_scale = 0.2

# Define RBF kernel
def RBF(x1, x2, params):
    output_scale, lengthscales = params
    diffs = np.expand_dims(x1 / lengthscales, 1) - \
            np.expand_dims(x2 / lengthscales, 0)
    r2 = np.sum(diffs**2, axis=2)
    return output_scale * np.exp(-0.5 * r2)

# Geneate training data corresponding to one input sample
def generate_one_training_data(key, m=100, P=1):
    # Sample GP prior at a fine grid
    N = 512
    gp_params = (1.0, length_scale)
    jitter = 1e-10
    X = np.linspace(0, 1, N)[:,None]
    K = RBF(X, X, gp_params)
    L = np.linalg.cholesky(K + jitter*np.eye(N))
    gp_sample = np.dot(L, random.normal(key, (N,)))

    # Create a callable interpolation function  
    u_fn = lambda x, t: np.interp(t, X.flatten(), gp_sample)

    # Input sensor locations and measurements
    x = np.linspace(0, 1, m)
    u = vmap(u_fn, in_axes=(None,0))(0.0, x)

    # Output sensor locations and measurements
    y_train = random.uniform(key, (P,)).sort() 
    s_train = odeint(u_fn, 0.0, np.hstack((0.0, y_train)))[1:] # JAX has a bug and always returns s(0), so add a dummy entry to y and return s[1:]

    # Tile inputs
    u_train = np.tile(u, (P,1))

    # training data for the residual
    u_r_train = np.tile(u, (m, 1))
    y_r_train = x
    s_r_train = u

    return u_train, y_train, s_train, u_r_train, y_r_train,  s_r_train

# Geneate test data corresponding to one input sample
def generate_one_test_data(key, m=100, P=100):
    # Sample GP prior at a fine grid
    N = 512
    gp_params = (1.0, length_scale)
    jitter = 1e-10
    X = np.linspace(0, 1, N)[:,None]
    K = RBF(X, X, gp_params)
    L = np.linalg.cholesky(K + jitter*np.eye(N))
    gp_sample = np.dot(L, random.normal(key, (N,)))

    # Create a callable interpolation function  
    u_fn = lambda x, t: np.interp(t, X.flatten(), gp_sample)

    # Input sensor locations and measurements
    x = np.linspace(0, 1, m)
    u = vmap(u_fn, in_axes=(None,0))(0.0, x)

    # Output sensor locations and measurements
    y = np.linspace(0, 1, P)
    s = odeint(u_fn, 0.0, y)

    # Tile inputs
    u = np.tile(u, (P,1))

    return u, y, s 

# Geneate training data corresponding to N input sample
def generate_training_data(key, N, m, P):
    config.update("jax_enable_x64", True)
    keys = random.split(key, N)
    gen_fn = jit(lambda key: generate_one_training_data(key, m, P))
    u_train, y_train, s_train, u_r_train, y_r_train, s_r_train = vmap(gen_fn)(keys)

    u_train = np.float32(u_train.reshape(N * P,-1))
    y_train = np.float32(y_train.reshape(N * P,-1))
    s_train = np.float32(s_train.reshape(N * P,-1))

    u_r_train = np.float32(u_r_train.reshape(N * m,-1))
    y_r_train = np.float32(y_r_train.reshape(N * m,-1))
    s_r_train = np.float32(s_r_train.reshape(N * m,-1))

    config.update("jax_enable_x64", False)
    return u_train, y_train, s_train, u_r_train, y_r_train,  s_r_train

# Geneate test data corresponding to N input sample
def generate_test_data(key, N, m, P):
    config.update("jax_enable_x64", True)
    keys = random.split(key, N)
    gen_fn = jit(lambda key: generate_one_test_data(key, m, P))
    u, y, s = vmap(gen_fn)(keys)
    u = np.float32(u.reshape(N * P,-1))
    y = np.float32(y.reshape(N * P,-1))
    s = np.float32(s.reshape(N * P,-1))

    config.update("jax_enable_x64", False)
    return u, y, s

# Compute relative l2 error over N test samples.
def compute_error(key, m, P):
    # Generate one test sample
    u_test, y_test, s_test = generate_test_data(key, 1, m, P)
    
    # Predict the solution and the residual
    s_pred = model.predict_s(params, u_test, y_test)[:,None]
    s_y_pred = model.predict_s_y(params, u_test, y_test)

    # Compute relative l2 error
    error_s = np.linalg.norm(s_test - s_pred) / np.linalg.norm(s_test) 
    error_u = np.linalg.norm(u_test[::P_test].flatten()[:,None] - s_y_pred) / np.linalg.norm(u_test[::P_test].flatten()[:,None]) 

    return error_s, error_u

# %%
N_train = 10000 # number of input samples
m = 100 # number of input sensors
P_train = 1   # number of output sensors
key_train = random.PRNGKey(0) # use different key for generating training data and test data 
u_train, y_train, s_train, u_r_train, y_r_train, s_r_train = generate_training_data(key_train, N_train, m, P_train)

# If solve the foward problem
# y_train = np.zeros((N_train, 1))
# s_train = np.zeros((N_train, 1))

# %%
# Initialize model
branch_layers = [m, 50, 50, 50, 50, 50]
trunk_layers =  [1, 50, 50, 50, 50, 50]
model = PI_DeepONet(branch_layers, trunk_layers)

# %%
# Create data set
batch_size = 10000
operator_dataset = DataGenerator(u_train, y_train, s_train, batch_size)
physics_dataset = DataGenerator(u_r_train, y_r_train, s_r_train, batch_size)

# %%
# Train
model.train(operator_dataset, physics_dataset, nIter=40000)
# Out:
#   0%|          | 0/40000 [00:00<?, ?it/s]
# 100%|██████████| 40000/40000 [02:38<00:00, 253.05it/s, Loss=5.234783e-05, loss_operator=1.1162713e-06, loss_physics=5.123156e-05]

# %%
# Compute test error
N_test = 1000 # number of input samples 
P_test = m   # number of sensors 
key_test = random.PRNGKey(12345) # A different key 
keys_test = random.split(key_test, N_test)

# Predict
params = model.get_params(model.opt_state)

# Compute errors over test dataset
error_s, error_u = vmap(compute_error, (0, None, None))(keys_test, m, P_test) 

print('mean of relative L2 error of s: {:.2e}'.format(error_s.mean()))
print('mean of relative L2 error of u: {:.2e}'.format(error_u.mean()))

print('std of relative L2 error of s: {:.2e}'.format(error_s.std()))
print('std L2 error of u: {:.2e}'.format(error_u.std()))
# Out:
# E1112 13:37:09.966298 3713372 buffer_comparator.cc:150] Difference at 18: nan, expected -inf
# E1112 13:37:09.966365 3713372 buffer_comparator.cc:150] Difference at 22: nan, expected -inf
# E1112 13:37:09.966371 3713372 buffer_comparator.cc:150] Difference at 30: nan, expected inf
# E1112 13:37:09.966373 3713372 buffer_comparator.cc:150] Difference at 32: nan, expected -inf
# E1112 13:37:09.966375 3713372 buffer_comparator.cc:150] Difference at 44: nan, expected inf
# E1112 13:37:09.966378 3713372 buffer_comparator.cc:150] Difference at 46: nan, expected inf
# E1112 13:37:09.966396 3713372 buffer_comparator.cc:150] Difference at 72: nan, expected -inf
# E1112 13:37:09.966399 3713372 buffer_comparator.cc:150] Difference at 74: nan, expected -inf
# E1112 13:37:09.966401 3713372 buffer_comparator.cc:150] Difference at 96: nan, expected -inf
# E1112 13:37:09.966404 3713372 buffer_comparator.cc:150] Difference at 108: nan, expected inf
# E1112 13:37:09.990727 3713372 buffer_comparator.cc:150] Difference at 18: nan, expected -inf
# E1112 13:37:09.990773 3713372 buffer_comparator.cc:150] Difference at 22: nan, expected -inf
# E1112 13:37:09.990777 3713372 buffer_comparator.cc:150] Difference at 30: nan, expected inf
# E1112 13:37:09.990780 3713372 buffer_comparator.cc:150] Difference at 32: nan, expected -inf
# E1112 13:37:09.990782 3713372 buffer_comparator.cc:150] Difference at 44: nan, expected inf
# E1112 13:37:09.990785 3713372 buffer_comparator.cc:150] Difference at 46: nan, expected inf
# E1112 13:37:09.990787 3713372 buffer_comparator.cc:150] Difference at 72: nan, expected -inf
# E1112 13:37:09.990806 3713372 buffer_comparator.cc:150] Difference at 74: nan, expected -inf
# E1112 13:37:09.990808 3713372 buffer_comparator.cc:150] Difference at 96: nan, expected -inf
# E1112 13:37:09.990811 3713372 buffer_comparator.cc:150] Difference at 108: nan, expected inf
# E1112 13:37:10.015221 3713372 buffer_comparator.cc:150] Difference at 18: nan, expected -inf
# E1112 13:37:10.015267 3713372 buffer_comparator.cc:150] Difference at 22: nan, expected -inf
# E1112 13:37:10.015273 3713372 buffer_comparator.cc:150] Difference at 30: nan, expected inf
# E1112 13:37:10.015275 3713372 buffer_comparator.cc:150] Difference at 32: nan, expected -inf
# E1112 13:37:10.015277 3713372 buffer_comparator.cc:150] Difference at 44: nan, expected inf
# E1112 13:37:10.015280 3713372 buffer_comparator.cc:150] Difference at 46: nan, expected inf
# E1112 13:37:10.015298 3713372 buffer_comparator.cc:150] Difference at 72: nan, expected -inf
# E1112 13:37:10.015300 3713372 buffer_comparator.cc:150] Difference at 74: nan, expected -inf
# E1112 13:37:10.015303 3713372 buffer_comparator.cc:150] Difference at 96: nan, expected -inf
# E1112 13:37:10.015305 3713372 buffer_comparator.cc:150] Difference at 108: nan, expected inf
# E1112 13:37:10.039760 3713372 buffer_comparator.cc:150] Difference at 18: nan, expected -inf
# E1112 13:37:10.039802 3713372 buffer_comparator.cc:150] Difference at 22: nan, expected -inf
# E1112 13:37:10.039807 3713372 buffer_comparator.cc:150] Difference at 30: nan, expected inf
# E1112 13:37:10.039810 3713372 buffer_comparator.cc:150] Difference at 32: nan, expected -inf
# E1112 13:37:10.039812 3713372 buffer_comparator.cc:150] Difference at 44: nan, expected inf
# E1112 13:37:10.039814 3713372 buffer_comparator.cc:150] Difference at 46: nan, expected inf
# E1112 13:37:10.039817 3713372 buffer_comparator.cc:150] Difference at 72: nan, expected -inf
# E1112 13:37:10.039819 3713372 buffer_comparator.cc:150] Difference at 74: nan, expected -inf
# E1112 13:37:10.039821 3713372 buffer_comparator.cc:150] Difference at 96: nan, expected -inf
# E1112 13:37:10.039824 3713372 buffer_comparator.cc:150] Difference at 108: nan, expected inf
# E1112 13:37:10.063668 3713372 buffer_comparator.cc:150] Difference at 18: nan, expected -inf
# E1112 13:37:10.063712 3713372 buffer_comparator.cc:150] Difference at 22: nan, expected -inf
# E1112 13:37:10.063716 3713372 buffer_comparator.cc:150] Difference at 30: nan, expected inf
# E1112 13:37:10.063719 3713372 buffer_comparator.cc:150] Difference at 32: nan, expected -inf
# E1112 13:37:10.063721 3713372 buffer_comparator.cc:150] Difference at 44: nan, expected inf
# E1112 13:37:10.063723 3713372 buffer_comparator.cc:150] Difference at 46: nan, expected inf
# E1112 13:37:10.063742 3713372 buffer_comparator.cc:150] Difference at 72: nan, expected -inf
# E1112 13:37:10.063744 3713372 buffer_comparator.cc:150] Difference at 74: nan, expected -inf
# E1112 13:37:10.063746 3713372 buffer_comparator.cc:150] Difference at 96: nan, expected -inf
# E1112 13:37:10.063749 3713372 buffer_comparator.cc:150] Difference at 108: nan, expected inf
# E1112 13:37:10.087672 3713372 buffer_comparator.cc:150] Difference at 18: nan, expected -inf
# E1112 13:37:10.087711 3713372 buffer_comparator.cc:150] Difference at 22: nan, expected -inf
# E1112 13:37:10.087715 3713372 buffer_comparator.cc:150] Difference at 24: nan, expected -inf
# E1112 13:37:10.087717 3713372 buffer_comparator.cc:150] Difference at 30: nan, expected inf
# E1112 13:37:10.087720 3713372 buffer_comparator.cc:150] Difference at 32: nan, expected -inf
# E1112 13:37:10.087722 3713372 buffer_comparator.cc:150] Difference at 44: nan, expected inf
# E1112 13:37:10.087725 3713372 buffer_comparator.cc:150] Difference at 46: nan, expected inf
# E1112 13:37:10.087727 3713372 buffer_comparator.cc:150] Difference at 64: nan, expected -inf
# E1112 13:37:10.087729 3713372 buffer_comparator.cc:150] Difference at 68: nan, expected -inf
# E1112 13:37:10.087732 3713372 buffer_comparator.cc:150] Difference at 72: nan, expected -inf
# E1112 13:37:10.112366 3713372 buffer_comparator.cc:150] Difference at 18: nan, expected -inf
# E1112 13:37:10.112404 3713372 buffer_comparator.cc:150] Difference at 22: nan, expected -inf
# E1112 13:37:10.112408 3713372 buffer_comparator.cc:150] Difference at 24: nan, expected -inf
# E1112 13:37:10.112410 3713372 buffer_comparator.cc:150] Difference at 30: nan, expected inf
# E1112 13:37:10.112413 3713372 buffer_comparator.cc:150] Difference at 32: nan, expected -inf
# E1112 13:37:10.112415 3713372 buffer_comparator.cc:150] Difference at 44: nan, expected inf
# E1112 13:37:10.112417 3713372 buffer_comparator.cc:150] Difference at 46: nan, expected inf
# E1112 13:37:10.112435 3713372 buffer_comparator.cc:150] Difference at 64: nan, expected -inf
# E1112 13:37:10.112438 3713372 buffer_comparator.cc:150] Difference at 68: nan, expected -inf
# E1112 13:37:10.112440 3713372 buffer_comparator.cc:150] Difference at 72: nan, expected -inf
# E1112 13:37:10.136259 3713372 buffer_comparator.cc:150] Difference at 18: nan, expected -inf
# E1112 13:37:10.136298 3713372 buffer_comparator.cc:150] Difference at 22: nan, expected -inf
# E1112 13:37:10.136302 3713372 buffer_comparator.cc:150] Difference at 24: nan, expected -inf
# E1112 13:37:10.136304 3713372 buffer_comparator.cc:150] Difference at 30: nan, expected inf
# E1112 13:37:10.136307 3713372 buffer_comparator.cc:150] Difference at 32: nan, expected -inf
# E1112 13:37:10.136309 3713372 buffer_comparator.cc:150] Difference at 44: nan, expected inf
# E1112 13:37:10.136311 3713372 buffer_comparator.cc:150] Difference at 46: nan, expected inf
# E1112 13:37:10.136329 3713372 buffer_comparator.cc:150] Difference at 64: nan, expected -inf
# E1112 13:37:10.136332 3713372 buffer_comparator.cc:150] Difference at 68: nan, expected -inf
# E1112 13:37:10.136334 3713372 buffer_comparator.cc:150] Difference at 72: nan, expected -inf
# E1112 13:37:10.160316 3713372 buffer_comparator.cc:150] Difference at 8: nan, expected inf
# E1112 13:37:10.160352 3713372 buffer_comparator.cc:150] Difference at 14: nan, expected inf
# E1112 13:37:10.160356 3713372 buffer_comparator.cc:150] Difference at 16: nan, expected inf
# E1112 13:37:10.160358 3713372 buffer_comparator.cc:150] Difference at 18: nan, expected -inf
# E1112 13:37:10.160361 3713372 buffer_comparator.cc:150] Difference at 22: nan, expected -inf
# E1112 13:37:10.160363 3713372 buffer_comparator.cc:150] Difference at 24: nan, expected -inf
# E1112 13:37:10.160365 3713372 buffer_comparator.cc:150] Difference at 26: nan, expected -inf
# E1112 13:37:10.160383 3713372 buffer_comparator.cc:150] Difference at 30: nan, expected inf
# E1112 13:37:10.160385 3713372 buffer_comparator.cc:150] Difference at 32: nan, expected -inf
# E1112 13:37:10.160388 3713372 buffer_comparator.cc:150] Difference at 40: nan, expected -inf
# E1112 13:37:10.184471 3713372 buffer_comparator.cc:150] Difference at 8: nan, expected inf
# E1112 13:37:10.184513 3713372 buffer_comparator.cc:150] Difference at 14: nan, expected inf
# E1112 13:37:10.184518 3713372 buffer_comparator.cc:150] Difference at 16: nan, expected inf
# E1112 13:37:10.184520 3713372 buffer_comparator.cc:150] Difference at 18: nan, expected -inf
# E1112 13:37:10.184522 3713372 buffer_comparator.cc:150] Difference at 22: nan, expected -inf
# E1112 13:37:10.184525 3713372 buffer_comparator.cc:150] Difference at 24: nan, expected -inf
# E1112 13:37:10.184527 3713372 buffer_comparator.cc:150] Difference at 26: nan, expected -inf
# E1112 13:37:10.184530 3713372 buffer_comparator.cc:150] Difference at 30: nan, expected inf
# E1112 13:37:10.184532 3713372 buffer_comparator.cc:150] Difference at 32: nan, expected -inf
# E1112 13:37:10.184534 3713372 buffer_comparator.cc:150] Difference at 40: nan, expected -inf
# E1112 13:37:10.209800 3713372 buffer_comparator.cc:150] Difference at 8: nan, expected inf
# E1112 13:37:10.209837 3713372 buffer_comparator.cc:150] Difference at 14: nan, expected inf
# E1112 13:37:10.209842 3713372 buffer_comparator.cc:150] Difference at 16: nan, expected inf
# E1112 13:37:10.209845 3713372 buffer_comparator.cc:150] Difference at 18: nan, expected -inf
# E1112 13:37:10.209847 3713372 buffer_comparator.cc:150] Difference at 22: nan, expected -inf
# E1112 13:37:10.209850 3713372 buffer_comparator.cc:150] Difference at 24: nan, expected -inf
# E1112 13:37:10.209853 3713372 buffer_comparator.cc:150] Difference at 26: nan, expected -inf
# E1112 13:37:10.209855 3713372 buffer_comparator.cc:150] Difference at 30: nan, expected inf
# E1112 13:37:10.209858 3713372 buffer_comparator.cc:150] Difference at 32: nan, expected -inf
# E1112 13:37:10.209860 3713372 buffer_comparator.cc:150] Difference at 40: nan, expected -inf
# E1112 13:37:10.240460 3713372 buffer_comparator.cc:150] Difference at 8: inf, expected nan
# E1112 13:37:10.240494 3713372 buffer_comparator.cc:150] Difference at 14: inf, expected nan
# E1112 13:37:10.240499 3713372 buffer_comparator.cc:150] Difference at 16: -inf, expected nan
# E1112 13:37:10.240501 3713372 buffer_comparator.cc:150] Difference at 22: inf, expected nan
# E1112 13:37:10.240503 3713372 buffer_comparator.cc:150] Difference at 28: -inf, expected nan
# E1112 13:37:10.240505 3713372 buffer_comparator.cc:150] Difference at 36: -inf, expected nan
# E1112 13:37:10.240508 3713372 buffer_comparator.cc:150] Difference at 40: -inf, expected nan
# E1112 13:37:10.240526 3713372 buffer_comparator.cc:150] Difference at 50: -inf, expected nan
# E1112 13:37:10.240528 3713372 buffer_comparator.cc:150] Difference at 54: inf, expected nan
# E1112 13:37:10.240530 3713372 buffer_comparator.cc:150] Difference at 58: inf, expected nan
# E1112 13:37:10.241148 3713372 buffer_comparator.cc:150] Difference at 8: inf, expected nan
# E1112 13:37:10.241162 3713372 buffer_comparator.cc:150] Difference at 14: inf, expected nan
# E1112 13:37:10.241166 3713372 buffer_comparator.cc:150] Difference at 16: -inf, expected nan
# E1112 13:37:10.241168 3713372 buffer_comparator.cc:150] Difference at 22: inf, expected nan
# E1112 13:37:10.241170 3713372 buffer_comparator.cc:150] Difference at 28: -inf, expected nan
# E1112 13:37:10.241173 3713372 buffer_comparator.cc:150] Difference at 36: -inf, expected nan
# E1112 13:37:10.241175 3713372 buffer_comparator.cc:150] Difference at 40: -inf, expected nan
# E1112 13:37:10.241178 3713372 buffer_comparator.cc:150] Difference at 50: -inf, expected nan
# E1112 13:37:10.241180 3713372 buffer_comparator.cc:150] Difference at 54: inf, expected nan
# E1112 13:37:10.241182 3713372 buffer_comparator.cc:150] Difference at 58: inf, expected nan
# E1112 13:37:10.241788 3713372 buffer_comparator.cc:150] Difference at 8: inf, expected nan
# E1112 13:37:10.241802 3713372 buffer_comparator.cc:150] Difference at 14: inf, expected nan
# E1112 13:37:10.241805 3713372 buffer_comparator.cc:150] Difference at 16: -inf, expected nan
# E1112 13:37:10.241807 3713372 buffer_comparator.cc:150] Difference at 22: inf, expected nan
# E1112 13:37:10.241810 3713372 buffer_comparator.cc:150] Difference at 28: -inf, expected nan
# E1112 13:37:10.241812 3713372 buffer_comparator.cc:150] Difference at 36: -inf, expected nan
# E1112 13:37:10.241815 3713372 buffer_comparator.cc:150] Difference at 40: -inf, expected nan
# E1112 13:37:10.241817 3713372 buffer_comparator.cc:150] Difference at 50: -inf, expected nan
# E1112 13:37:10.241819 3713372 buffer_comparator.cc:150] Difference at 54: inf, expected nan
# E1112 13:37:10.241822 3713372 buffer_comparator.cc:150] Difference at 58: inf, expected nan
# E1112 13:37:10.242452 3713372 buffer_comparator.cc:150] Difference at 8: inf, expected nan
# E1112 13:37:10.242465 3713372 buffer_comparator.cc:150] Difference at 14: inf, expected nan
# E1112 13:37:10.242468 3713372 buffer_comparator.cc:150] Difference at 16: -inf, expected nan
# E1112 13:37:10.242470 3713372 buffer_comparator.cc:150] Difference at 22: inf, expected nan
# E1112 13:37:10.242473 3713372 buffer_comparator.cc:150] Difference at 28: -inf, expected nan
# E1112 13:37:10.242475 3713372 buffer_comparator.cc:150] Difference at 36: -inf, expected nan
# E1112 13:37:10.242478 3713372 buffer_comparator.cc:150] Difference at 40: -inf, expected nan
# E1112 13:37:10.242480 3713372 buffer_comparator.cc:150] Difference at 50: -inf, expected nan
# E1112 13:37:10.242482 3713372 buffer_comparator.cc:150] Difference at 54: inf, expected nan
# E1112 13:37:10.242485 3713372 buffer_comparator.cc:150] Difference at 58: inf, expected nan
# E1112 13:37:10.243100 3713372 buffer_comparator.cc:150] Difference at 8: inf, expected nan
# E1112 13:37:10.243113 3713372 buffer_comparator.cc:150] Difference at 14: inf, expected nan
# E1112 13:37:10.243116 3713372 buffer_comparator.cc:150] Difference at 16: -inf, expected nan
# E1112 13:37:10.243118 3713372 buffer_comparator.cc:150] Difference at 22: inf, expected nan
# E1112 13:37:10.243121 3713372 buffer_comparator.cc:150] Difference at 28: -inf, expected nan
# E1112 13:37:10.243124 3713372 buffer_comparator.cc:150] Difference at 36: -inf, expected nan
# E1112 13:37:10.243126 3713372 buffer_comparator.cc:150] Difference at 40: -inf, expected nan
# E1112 13:37:10.243128 3713372 buffer_comparator.cc:150] Difference at 50: -inf, expected nan
# E1112 13:37:10.243131 3713372 buffer_comparator.cc:150] Difference at 54: inf, expected nan
# E1112 13:37:10.243133 3713372 buffer_comparator.cc:150] Difference at 58: inf, expected nan
# E1112 13:37:10.243748 3713372 buffer_comparator.cc:150] Difference at 50: -inf, expected nan
# E1112 13:37:10.243760 3713372 buffer_comparator.cc:150] Difference at 58: inf, expected nan
# E1112 13:37:10.243763 3713372 buffer_comparator.cc:150] Difference at 64: inf, expected nan
# E1112 13:37:10.243766 3713372 buffer_comparator.cc:150] Difference at 66: -inf, expected nan
# E1112 13:37:10.243768 3713372 buffer_comparator.cc:150] Difference at 68: inf, expected nan
# E1112 13:37:10.243770 3713372 buffer_comparator.cc:150] Difference at 72: inf, expected nan
# E1112 13:37:10.243773 3713372 buffer_comparator.cc:150] Difference at 78: -inf, expected nan
# E1112 13:37:10.243775 3713372 buffer_comparator.cc:150] Difference at 80: -inf, expected nan
# E1112 13:37:10.243777 3713372 buffer_comparator.cc:150] Difference at 82: -inf, expected nan
# E1112 13:37:10.243779 3713372 buffer_comparator.cc:150] Difference at 86: inf, expected nan
# E1112 13:37:10.244389 3713372 buffer_comparator.cc:150] Difference at 50: -inf, expected nan
# E1112 13:37:10.244401 3713372 buffer_comparator.cc:150] Difference at 58: inf, expected nan
# E1112 13:37:10.244404 3713372 buffer_comparator.cc:150] Difference at 64: inf, expected nan
# E1112 13:37:10.244407 3713372 buffer_comparator.cc:150] Difference at 66: -inf, expected nan
# E1112 13:37:10.244409 3713372 buffer_comparator.cc:150] Difference at 68: inf, expected nan
# E1112 13:37:10.244412 3713372 buffer_comparator.cc:150] Difference at 72: inf, expected nan
# E1112 13:37:10.244414 3713372 buffer_comparator.cc:150] Difference at 78: -inf, expected nan
# E1112 13:37:10.244416 3713372 buffer_comparator.cc:150] Difference at 80: -inf, expected nan
# E1112 13:37:10.244418 3713372 buffer_comparator.cc:150] Difference at 82: -inf, expected nan
# E1112 13:37:10.244420 3713372 buffer_comparator.cc:150] Difference at 86: inf, expected nan
# E1112 13:37:10.245067 3713372 buffer_comparator.cc:150] Difference at 50: -inf, expected nan
# E1112 13:37:10.245080 3713372 buffer_comparator.cc:150] Difference at 58: inf, expected nan
# E1112 13:37:10.245084 3713372 buffer_comparator.cc:150] Difference at 64: inf, expected nan
# E1112 13:37:10.245086 3713372 buffer_comparator.cc:150] Difference at 66: -inf, expected nan
# E1112 13:37:10.245088 3713372 buffer_comparator.cc:150] Difference at 68: inf, expected nan
# E1112 13:37:10.245091 3713372 buffer_comparator.cc:150] Difference at 72: inf, expected nan
# E1112 13:37:10.245093 3713372 buffer_comparator.cc:150] Difference at 78: -inf, expected nan
# E1112 13:37:10.245095 3713372 buffer_comparator.cc:150] Difference at 80: -inf, expected nan
# E1112 13:37:10.245097 3713372 buffer_comparator.cc:150] Difference at 82: -inf, expected nan
# E1112 13:37:10.245100 3713372 buffer_comparator.cc:150] Difference at 86: inf, expected nan
# E1112 13:37:10.245718 3713372 buffer_comparator.cc:150] Difference at 50: -inf, expected nan
# E1112 13:37:10.245731 3713372 buffer_comparator.cc:150] Difference at 58: inf, expected nan
# E1112 13:37:10.245735 3713372 buffer_comparator.cc:150] Difference at 64: inf, expected nan
# E1112 13:37:10.245737 3713372 buffer_comparator.cc:150] Difference at 66: -inf, expected nan
# E1112 13:37:10.245739 3713372 buffer_comparator.cc:150] Difference at 68: inf, expected nan
# E1112 13:37:10.245742 3713372 buffer_comparator.cc:150] Difference at 72: inf, expected nan
# E1112 13:37:10.245744 3713372 buffer_comparator.cc:150] Difference at 78: -inf, expected nan
# E1112 13:37:10.245747 3713372 buffer_comparator.cc:150] Difference at 80: -inf, expected nan
# E1112 13:37:10.245749 3713372 buffer_comparator.cc:150] Difference at 82: -inf, expected nan
# E1112 13:37:10.245751 3713372 buffer_comparator.cc:150] Difference at 86: inf, expected nan
# E1112 13:37:10.246376 3713372 buffer_comparator.cc:150] Difference at 50: -inf, expected nan
# E1112 13:37:10.246389 3713372 buffer_comparator.cc:150] Difference at 58: inf, expected nan
# E1112 13:37:10.246392 3713372 buffer_comparator.cc:150] Difference at 64: inf, expected nan
# E1112 13:37:10.246394 3713372 buffer_comparator.cc:150] Difference at 66: -inf, expected nan
# E1112 13:37:10.246397 3713372 buffer_comparator.cc:150] Difference at 68: inf, expected nan
# E1112 13:37:10.246399 3713372 buffer_comparator.cc:150] Difference at 72: inf, expected nan
# E1112 13:37:10.246402 3713372 buffer_comparator.cc:150] Difference at 78: -inf, expected nan
# E1112 13:37:10.246404 3713372 buffer_comparator.cc:150] Difference at 80: -inf, expected nan
# E1112 13:37:10.246406 3713372 buffer_comparator.cc:150] Difference at 82: -inf, expected nan
# E1112 13:37:10.246408 3713372 buffer_comparator.cc:150] Difference at 86: inf, expected nan
# E1112 13:37:10.248702 3713372 buffer_comparator.cc:150] Difference at 18: nan, expected -inf
# E1112 13:37:10.248716 3713372 buffer_comparator.cc:150] Difference at 30: nan, expected inf
# E1112 13:37:10.248720 3713372 buffer_comparator.cc:150] Difference at 44: nan, expected -inf
# E1112 13:37:10.248722 3713372 buffer_comparator.cc:150] Difference at 48: nan, expected -inf
# E1112 13:37:10.248725 3713372 buffer_comparator.cc:150] Difference at 156: inf, expected 3.3726e+38
# E1112 13:37:10.248731 3713372 buffer_comparator.cc:150] Difference at 218: nan, expected -inf
# E1112 13:37:10.248749 3713372 buffer_comparator.cc:150] Difference at 230: nan, expected inf
# E1112 13:37:10.248751 3713372 buffer_comparator.cc:150] Difference at 244: nan, expected -inf
# E1112 13:37:10.248754 3713372 buffer_comparator.cc:150] Difference at 248: nan, expected -inf
# E1112 13:37:10.248756 3713372 buffer_comparator.cc:150] Difference at 356: inf, expected 3.3726e+38
# E1112 13:37:10.249366 3713372 buffer_comparator.cc:150] Difference at 18: nan, expected -inf
# E1112 13:37:10.249378 3713372 buffer_comparator.cc:150] Difference at 30: nan, expected inf
# E1112 13:37:10.249381 3713372 buffer_comparator.cc:150] Difference at 44: nan, expected -inf
# E1112 13:37:10.249384 3713372 buffer_comparator.cc:150] Difference at 48: nan, expected -inf
# E1112 13:37:10.249386 3713372 buffer_comparator.cc:150] Difference at 156: inf, expected 3.3726e+38
# E1112 13:37:10.249391 3713372 buffer_comparator.cc:150] Difference at 218: nan, expected -inf
# E1112 13:37:10.249393 3713372 buffer_comparator.cc:150] Difference at 230: nan, expected inf
# E1112 13:37:10.249396 3713372 buffer_comparator.cc:150] Difference at 244: nan, expected -inf
# E1112 13:37:10.249398 3713372 buffer_comparator.cc:150] Difference at 248: nan, expected -inf
# E1112 13:37:10.249401 3713372 buffer_comparator.cc:150] Difference at 356: inf, expected 3.3726e+38
# E1112 13:37:10.250021 3713372 buffer_comparator.cc:150] Difference at 18: nan, expected -inf
# E1112 13:37:10.250034 3713372 buffer_comparator.cc:150] Difference at 30: nan, expected inf
# E1112 13:37:10.250037 3713372 buffer_comparator.cc:150] Difference at 44: nan, expected -inf
# E1112 13:37:10.250040 3713372 buffer_comparator.cc:150] Difference at 48: nan, expected -inf
# E1112 13:37:10.250042 3713372 buffer_comparator.cc:150] Difference at 156: inf, expected 3.3726e+38
# E1112 13:37:10.250047 3713372 buffer_comparator.cc:150] Difference at 218: nan, expected -inf
# E1112 13:37:10.250049 3713372 buffer_comparator.cc:150] Difference at 230: nan, expected inf
# E1112 13:37:10.250052 3713372 buffer_comparator.cc:150] Difference at 244: nan, expected -inf
# E1112 13:37:10.250054 3713372 buffer_comparator.cc:150] Difference at 248: nan, expected -inf
# E1112 13:37:10.250056 3713372 buffer_comparator.cc:150] Difference at 356: inf, expected 3.3726e+38
# mean of relative L2 error of s: 3.26e-03
# mean of relative L2 error of u: 7.96e-03
# std of relative L2 error of s: 2.86e-03
# std L2 error of u: 4.22e-03

# %%
#Plot for loss function
plt.figure(figsize = (6,5))
# plt.plot(model.loss_log, lw=2)
plt.plot(model.loss_operator_log, lw=2, label='operator')
plt.plot(model.loss_physics_log, lw=2, label='physics')

plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.yscale('log')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Generate test data
N_test = 100
P_test = m
key_test = random.PRNGKey(12345)
keys_test = random.split(key_test, N_test)

u_test, y_test, s_test =  generate_test_data(key_test, N_test, m, m)

params = model.get_params(model.opt_state)

# Model predictions
s_pred = model.predict_s(params, u_test, y_test)[:,None]
s_y_pred = model.predict_s_y(params, u_test, y_test)

# %%
# Plot for one generated data
# idx = onp.random.randint(N_test) # random visualizations
idx=0
index = np.arange(idx * P_test,(idx + 1) * P_test)

# Compute the relative l2 error for one input sample 
error_u = np.linalg.norm(s_test[index, :] - s_pred[index, :], 2) / np.linalg.norm(s_test[index, :], 2) 
error_s = np.linalg.norm(u_test[::P_test][idx].flatten()[:,None] - s_y_pred[index, :], 2) / np.linalg.norm(u_test[::P_test][idx].flatten()[:,None], 2) 

print("error_u: {:.3e}".format(error_u))
print("error_s: {:.3e}".format(error_s))

# Visualizations
# Predicted solution s(y)
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(y_test[index, :], s_test[index, :], label='Exact s', lw=2)
plt.plot(y_test[index, :], s_pred[index, :], '--', label='Predicted s', lw=2)
plt.xlabel('y')
plt.ylabel('s(y)')
plt.tight_layout()
plt.legend()

plt.subplot(1,2,2)
plt.plot(y_test[index, :], s_pred[index, :] - s_test[index, :], '--', lw=2, label='error')
plt.tight_layout()
plt.legend()
plt.show()

# Predicted residual u(x)
fig = plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(y_test[index, :], u_test[::P_test][idx], label='Exact u', lw=2)
plt.plot(y_test[index, :], s_y_pred[index,:], '--', label='Predicted u', lw=2)
plt.legend()
plt.tight_layout()

plt.subplot(1,2,2)
plt.plot(y_test[index, :], s_y_pred[index,:].flatten() - u_test[::P_test][idx] , '--', label='error', lw=2)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# error_u: 2.162e-03
# error_s: 9.766e-03
